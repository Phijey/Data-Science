# %% [markdown]
# ## AULA 01

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/bicicletas.csv')

# %%
df.head()
# Out:
#              data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04 00:00:00       182          3.0               2.0     93.0
# 1  2015-01-04 01:00:00       138          NaN               NaN     93.0
# 2  2015-01-04 02:00:00       134          2.5               2.5     96.5
# 3  2015-01-04 03:00:00        72          2.0               2.0    100.0
# 4  2015-01-04 04:00:00        47          NaN               NaN     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao
# 0               6.0    Nublado     Não           Sim  Inverno
# 1               5.0  Céu limpo     Não           Sim  Inverno
# 2               0.0  Céu limpo     Não           Sim  Inverno
# 3               0.0  Céu limpo     Não           Sim  Inverno
# 4               6.5  Céu limpo     Não           Sim  Inverno

# %%
df.shape
# Out:
# (17429, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17429 entries, 0 to 17428
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_hora         17429 non-null  object
#  1   contagem          17429 non-null  int64
#  2   temperatura       17406 non-null  float64
#  3   sensacao_termica  17406 non-null  float64
#  4   umidade           17429 non-null  float64
#  5   velocidade_vento  17429 non-null  float64
#  6   clima             17429 non-null  object
#  7   feriado           17429 non-null  object
#  8   fim_de_semana     17429 non-null  object
#  9   estacao           17429 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
# Contando os nulos
df.isnull().sum()
# Out:
# data_hora            0
# contagem             0
# temperatura         23
# sensacao_termica    23
# umidade              0
# velocidade_vento     0
# clima                0
# feriado              0
# fim_de_semana        0
# estacao              0
# dtype: int64

# %%
df['temperatura'] = df['temperatura'].interpolate(method='linear')
df['sensacao_termica'] = df['sensacao_termica'].interpolate(method='linear')

# %%
df.head(10)
# Out:
#              data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04 00:00:00       182         3.00              2.00     93.0
# 1  2015-01-04 01:00:00       138         2.75              2.25     93.0
# 2  2015-01-04 02:00:00       134         2.50              2.50     96.5
# 3  2015-01-04 03:00:00        72         2.00              2.00    100.0
# 4  2015-01-04 04:00:00        47         2.00              2.00     93.0
# 5  2015-01-04 05:00:00        46         2.00              2.00     93.0
# 6  2015-01-04 06:00:00        51         1.00             -1.00    100.0
# 7  2015-01-04 07:00:00        75         1.00             -1.00    100.0
# 8  2015-01-04 08:00:00       131         1.50             -1.00     96.5
# 9  2015-01-04 09:00:00       301         2.00             -0.50    100.0
#
#    velocidade_vento                 clima feriado fim_de_semana  estacao
# 0               6.0               Nublado     Não           Sim  Inverno
# 1               5.0             Céu limpo     Não           Sim  Inverno
# 2               0.0             Céu limpo     Não           Sim  Inverno
# 3               0.0             Céu limpo     Não           Sim  Inverno
# 4               6.5             Céu limpo     Não           Sim  Inverno
# 5               4.0             Céu limpo     Não           Sim  Inverno
# 6               7.0  Parcialmente nublado     Não           Sim  Inverno
# 7               7.0  Parcialmente nublado     Não           Sim  Inverno
# 8               8.0  Parcialmente nublado     Não           Sim  Inverno
# 9               9.0               Nublado     Não           Sim  Inverno

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
df.duplicated(keep= False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17424     True
# 17425     True
# 17426     True
# 17427     True
# 17428     True
# Length: 17429, dtype: bool

# %%
duplicatas = df.duplicated(keep= False)
linhas_duplicadas = df[duplicatas]

# %%
# Desordenadas
linhas_duplicadas
# Out:
#                  data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 519    2015-01-25 16:00:00      1238          8.0               5.0     71.0
# 869    2015-02-09 06:00:00       479          5.0               3.5     87.0
# 3655   2015-06-05 18:00:00      3411         23.0              23.0     50.0
# 4167   2015-06-27 02:00:00       337         15.5              15.5     74.5
# 4658   2015-07-17 14:00:00      1882         24.5              24.5     44.0
# 5360   2015-08-15 23:00:00       759         17.0              17.0     59.0
# 8174   2015-12-12 11:00:00      1100         12.0              12.0     82.0
# 8175   2015-12-12 12:00:00      1308         13.0              13.0     77.0
# 8528   2015-12-27 05:00:00        57         15.0              15.0     72.0
# 9428   2016-02-02 17:00:00      2846          8.0               4.5     59.5
# 11646  2016-05-06 03:00:00        77          9.5               9.0     79.0
# 12350  2016-06-04 11:00:00      1779         15.5              15.5     85.5
# 12443  2016-06-08 08:00:00      4672         18.0              18.0     83.0
# 16848  2016-12-11 10:00:00      1098          7.5               4.5     87.0
# 17128  2016-12-23 02:00:00        92          7.5               5.5     90.0
# 17414  2016-05-06 03:00:00        77          9.5               9.0     79.0
# 17415  2015-12-27 05:00:00        57         15.0              15.0     72.0
# 17416  2016-06-08 08:00:00      4672         18.0              18.0     83.0
# 17417  2015-02-09 06:00:00       479          5.0               3.5     87.0
# 17418  2015-07-17 14:00:00      1882         24.5              24.5     44.0
# 17419  2016-06-04 11:00:00      1779         15.5              15.5     85.5
# 17420  2015-12-12 12:00:00      1308         13.0              13.0     77.0
# 17421  2015-06-27 02:00:00       337         15.5              15.5     74.5
# 17422  2015-01-25 16:00:00      1238          8.0               5.0     71.0
# 17423  2016-12-23 02:00:00        92          7.5               5.5     90.0
# 17424  2016-12-11 10:00:00      1098          7.5               4.5     87.0
# 17425  2015-06-05 18:00:00      3411         23.0              23.0     50.0
# 17426  2015-12-12 11:00:00      1100         12.0              12.0     82.0
# 17427  2016-02-02 17:00:00      2846          8.0               4.5     59.5
# 17428  2015-08-15 23:00:00       759         17.0              17.0     59.0
#
#        velocidade_vento                 clima feriado fim_de_semana    estacao
# 519                18.0               Nublado     Não           Sim    Inverno
# 869                 6.5  Parcialmente nublado     Não           Não    Inverno
# 3655               26.0  Parcialmente nublado     Não           Não      Verão
# 4167               18.0  Parcialmente nublado     Não           Sim      Verão
# 4658               29.5  Parcialmente nublado     Não           Não      Verão
# 5360                6.0             Céu limpo     Não           Sim      Verão
# 8174               20.0            Chuva leve     Não           Sim    Inverno
# 8175               26.0            Chuva leve     Não           Sim    Inverno
# 8528               31.0  Parcialmente nublado     Não           Sim    Inverno
# 9428               23.0  Parcialmente nublado     Não           Não    Inverno
# 11646               6.0             Céu limpo     Não           Não  Primavera
# 12350               8.0               Nublado     Não           Sim      Verão
# 12443               2.0             Céu limpo     Não           Não      Verão
# 16848              16.0             Céu limpo     Não           Sim    Inverno
# 17128              10.0             Céu limpo     Não           Não    Inverno
# 17414               6.0             Céu limpo     Não           Não  Primavera
# 17415              31.0  Parcialmente nublado     Não           Sim    Inverno
# 17416               2.0             Céu limpo     Não           Não      Verão
# 17417               6.5  Parcialmente nublado     Não           Não    Inverno
# 17418              29.5  Parcialmente nublado     Não           Não      Verão
# 17419               8.0               Nublado     Não           Sim      Verão
# 17420              26.0            Chuva leve     Não           Sim    Inverno
# 17421              18.0  Parcialmente nublado     Não           Sim      Verão
# 17422              18.0               Nublado     Não           Sim    Inverno
# 17423              10.0             Céu limpo     Não           Não    Inverno
# 17424              16.0             Céu limpo     Não           Sim    Inverno
# 17425              26.0  Parcialmente nublado     Não           Não      Verão
# 17426              20.0            Chuva leve     Não           Sim    Inverno
# 17427              23.0  Parcialmente nublado     Não           Não    Inverno
# 17428               6.0             Céu limpo     Não           Sim      Verão

# %%
# Ordenadas
linhas_duplicadas.sort_values(by = 'data_hora')
# Out:
#                  data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 519    2015-01-25 16:00:00      1238          8.0               5.0     71.0
# 17422  2015-01-25 16:00:00      1238          8.0               5.0     71.0
# 869    2015-02-09 06:00:00       479          5.0               3.5     87.0
# 17417  2015-02-09 06:00:00       479          5.0               3.5     87.0
# 3655   2015-06-05 18:00:00      3411         23.0              23.0     50.0
# 17425  2015-06-05 18:00:00      3411         23.0              23.0     50.0
# 4167   2015-06-27 02:00:00       337         15.5              15.5     74.5
# 17421  2015-06-27 02:00:00       337         15.5              15.5     74.5
# 4658   2015-07-17 14:00:00      1882         24.5              24.5     44.0
# 17418  2015-07-17 14:00:00      1882         24.5              24.5     44.0
# 17428  2015-08-15 23:00:00       759         17.0              17.0     59.0
# 5360   2015-08-15 23:00:00       759         17.0              17.0     59.0
# 17426  2015-12-12 11:00:00      1100         12.0              12.0     82.0
# 8174   2015-12-12 11:00:00      1100         12.0              12.0     82.0
# 17420  2015-12-12 12:00:00      1308         13.0              13.0     77.0
# 8175   2015-12-12 12:00:00      1308         13.0              13.0     77.0
# 17415  2015-12-27 05:00:00        57         15.0              15.0     72.0
# 8528   2015-12-27 05:00:00        57         15.0              15.0     72.0
# 17427  2016-02-02 17:00:00      2846          8.0               4.5     59.5
# 9428   2016-02-02 17:00:00      2846          8.0               4.5     59.5
# 17414  2016-05-06 03:00:00        77          9.5               9.0     79.0
# 11646  2016-05-06 03:00:00        77          9.5               9.0     79.0
# 12350  2016-06-04 11:00:00      1779         15.5              15.5     85.5
# 17419  2016-06-04 11:00:00      1779         15.5              15.5     85.5
# 12443  2016-06-08 08:00:00      4672         18.0              18.0     83.0
# 17416  2016-06-08 08:00:00      4672         18.0              18.0     83.0
# 17424  2016-12-11 10:00:00      1098          7.5               4.5     87.0
# 16848  2016-12-11 10:00:00      1098          7.5               4.5     87.0
# 17423  2016-12-23 02:00:00        92          7.5               5.5     90.0
# 17128  2016-12-23 02:00:00        92          7.5               5.5     90.0
#
#        velocidade_vento                 clima feriado fim_de_semana    estacao
# 519                18.0               Nublado     Não           Sim    Inverno
# 17422              18.0               Nublado     Não           Sim    Inverno
# 869                 6.5  Parcialmente nublado     Não           Não    Inverno
# 17417               6.5  Parcialmente nublado     Não           Não    Inverno
# 3655               26.0  Parcialmente nublado     Não           Não      Verão
# 17425              26.0  Parcialmente nublado     Não           Não      Verão
# 4167               18.0  Parcialmente nublado     Não           Sim      Verão
# 17421              18.0  Parcialmente nublado     Não           Sim      Verão
# 4658               29.5  Parcialmente nublado     Não           Não      Verão
# 17418              29.5  Parcialmente nublado     Não           Não      Verão
# 17428               6.0             Céu limpo     Não           Sim      Verão
# 5360                6.0             Céu limpo     Não           Sim      Verão
# 17426              20.0            Chuva leve     Não           Sim    Inverno
# 8174               20.0            Chuva leve     Não           Sim    Inverno
# 17420              26.0            Chuva leve     Não           Sim    Inverno
# 8175               26.0            Chuva leve     Não           Sim    Inverno
# 17415              31.0  Parcialmente nublado     Não           Sim    Inverno
# 8528               31.0  Parcialmente nublado     Não           Sim    Inverno
# 17427              23.0  Parcialmente nublado     Não           Não    Inverno
# 9428               23.0  Parcialmente nublado     Não           Não    Inverno
# 17414               6.0             Céu limpo     Não           Não  Primavera
# 11646               6.0             Céu limpo     Não           Não  Primavera
# 12350               8.0               Nublado     Não           Sim      Verão
# 17419               8.0               Nublado     Não           Sim      Verão
# 12443               2.0             Céu limpo     Não           Não      Verão
# 17416               2.0             Céu limpo     Não           Não      Verão
# 17424              16.0             Céu limpo     Não           Sim    Inverno
# 16848              16.0             Céu limpo     Não           Sim    Inverno
# 17423              10.0             Céu limpo     Não           Não    Inverno
# 17128              10.0             Céu limpo     Não           Não    Inverno

# %%
df_limpo = df.drop_duplicates()

# %%
df_limpo.shape
# Out:
# (17414, 10)

# %% [markdown]
# ## AULA 02

# %%
df_limpo.describe()
# Out:
#            contagem   temperatura  sensacao_termica       umidade  \
# count  17414.000000  17414.000000      17414.000000  17414.000000
# mean    1143.101642     12.468206         11.521080     72.324954
# std     1085.108068      5.571670          6.614799     14.313186
# min        0.000000     -1.500000         -6.000000     20.500000
# 25%      257.000000      8.000000          6.000000     63.000000
# 50%      844.000000     12.500000         12.500000     74.500000
# 75%     1671.750000     16.000000         16.000000     83.000000
# max     7860.000000     34.000000         34.000000    100.000000
#
#        velocidade_vento
# count      17414.000000
# mean          15.913063
# std            7.894570
# min            0.000000
# 25%           10.000000
# 50%           15.000000
# 75%           20.500000
# max           56.500000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(df_limpo, x='temperatura', bins=10)
plt.show()

# %%
sns.displot(df_limpo, x='sensacao_termica', bins=10)
plt.show()

# %%
sns.displot(df_limpo, x='umidade', bins=10)
plt.show()

# %%
sns.displot(df_limpo, x='velocidade_vento', bins=10)
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

sns.scatterplot(ax=axes[0,0], data=df_limpo, x='temperatura', y='contagem', color = 'red' )
axes[0,0].set_title('Temperatura vs Contagem')
sns.scatterplot(ax=axes[0,1], data=df_limpo, x='sensacao_termica', y='contagem', color = 'purple' )
axes[0,1].set_title('Sensação Termica vs Contagem')
sns.scatterplot(ax=axes[1,0], data=df_limpo, x='umidade', y='contagem', color = 'green' )
axes[1,0].set_title('Umidade vs Contagem')
sns.scatterplot(ax=axes[1,1], data=df_limpo, x='velocidade_vento', y='contagem', color = 'blue' )
axes[1,1].set_title('Velocidade Vento vs Contagem')
# Out:
# Text(0.5, 1.0, 'Velocidade Vento vs Contagem')

# %%
plt.figure(figsize = (8,4))
sns.heatmap(df_limpo.corr(numeric_only=True), annot = True, cmap = 'Blues')
plt.show()

# %% [markdown]
# ## AULA 03

# %%
df_limpo.describe(include = [object])
# Out:
#                   data_hora      clima feriado fim_de_semana    estacao
# count                 17414      17414   17414         17414      17414
# unique                17414          6       2             2          4
# top     2017-01-03 23:00:00  Céu limpo     Não           Não  Primavera
# freq                      1       6150   17030         12444       4394

# %%
for col in ['clima', 'feriado', 'fim_de_semana', 'estacao']:
  print(f"Coluna: {col}")
  print(df_limpo[col].unique())
  print('='*30, '\n')
# Out:
# Coluna: clima
# ['Nublado' 'Céu limpo' 'Parcialmente nublado' 'Chuva leve' 'Neve'
#  'Chuva com trovoadas']
# ==============================
#
# Coluna: feriado
# ['Não' 'Sim']
# ==============================
#
# Coluna: fim_de_semana
# ['Sim' 'Não']
# ==============================
#
# Coluna: estacao
# ['Inverno' 'Primavera' 'Verão' 'Outono']
# ==============================

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x = 'feriado', y = 'contagem', data = df_limpo)
plt.title('Aluguéis de bicicletas em dias normais VS Feriados')
plt.xlabel('feriado')
plt.ylabel('numero de aluguéis')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x = 'fim_de_semana', y = 'contagem', data = df_limpo)
plt.title('Aluguéis de bicicletas em dias normais VS Finais de Semana')
plt.xlabel('Final_Semana')
plt.ylabel('numero de aluguéis')
plt.show()

# %%
mediana_feriado = df_limpo.groupby('feriado')['contagem'].median()
mediana_fim_de_semana = df_limpo.groupby('fim_de_semana')['contagem'].median()

# %%
mediana_feriado
# Out:
# feriado
# Não    855.0
# Sim    439.5
# Name: contagem, dtype: float64

# %%
mediana_fim_de_semana
# Out:
# fim_de_semana
# Não    927.0
# Sim    619.0
# Name: contagem, dtype: float64

# %%
df_clima = df_limpo.groupby('clima')['contagem'].sum().reset_index()

# %%
df_clima
# Out:
#                   clima  contagem
# 0   Chuva com trovoadas      8168
# 1            Chuva leve   1526461
# 2             Céu limpo   7146847
# 3                  Neve     15051
# 4               Nublado   4243887
# 5  Parcialmente nublado   6965558

# %%
# ordenando no dataframe
df_clima = df_limpo.groupby('clima')['contagem'].sum().reset_index().sort_values(by = 'contagem', ascending=False)

# %%
df_clima
# Out:
#                   clima  contagem
# 2             Céu limpo   7146847
# 5  Parcialmente nublado   6965558
# 4               Nublado   4243887
# 1            Chuva leve   1526461
# 3                  Neve     15051
# 0   Chuva com trovoadas      8168

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=df_clima, x = 'contagem', y = 'clima', hue = 'clima', palette = 'Blues_r', orient = 'h')
plt.title('Bicicletas alugadas por clima')
plt.xlabel('Contagem')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize = (8,4))
paleta_cores = {'Primavera':'green', 'Verão':'orange', 'Outono':'brown', 'Inverno':'blue' }
sns.boxplot(data = df_limpo, x='estacao', y='contagem', hue='estacao', palette=paleta_cores)
plt.title('Aluguéis de bicicletas por estações do ano')
plt.xlabel('Estação do Ano')
plt.ylabel('Contagem')
plt.show()

# %%
df_limpo.groupby('estacao')['contagem'].median()
# Out:
# estacao
# Inverno       632.0
# Outono        898.0
# Primavera     823.0
# Verão        1214.0
# Name: contagem, dtype: float64

# %%
from scipy.stats import mannwhitneyu

primavera = df_limpo[df_limpo['estacao'] == 'Primavera']['contagem']
outono = df_limpo[df_limpo['estacao'] == 'Outono']['contagem']

u_statistic, p_value = mannwhitneyu(primavera, outono, alternative='two-sided')
u_statistic, p_value
# Out:
# (np.float64(9044682.5), np.float64(0.0004762100221646296))

# %% [markdown]
# ## AULA 04

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_hora         17414 non-null  object
#  1   contagem          17414 non-null  int64
#  2   temperatura       17414 non-null  float64
#  3   sensacao_termica  17414 non-null  float64
#  4   umidade           17414 non-null  float64
#  5   velocidade_vento  17414 non-null  float64
#  6   clima             17414 non-null  object
#  7   feriado           17414 non-null  object
#  8   fim_de_semana     17414 non-null  object
#  9   estacao           17414 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 1.5+ MB

# %%
df_data = df_limpo.copy()

# %%
df_data['data_hora'] = pd.to_datetime(df_data['data_hora'])
df_data.head()
# Out:
#             data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0 2015-01-04 00:00:00       182         3.00              2.00     93.0
# 1 2015-01-04 01:00:00       138         2.75              2.25     93.0
# 2 2015-01-04 02:00:00       134         2.50              2.50     96.5
# 3 2015-01-04 03:00:00        72         2.00              2.00    100.0
# 4 2015-01-04 04:00:00        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao
# 0               6.0    Nublado     Não           Sim  Inverno
# 1               5.0  Céu limpo     Não           Sim  Inverno
# 2               0.0  Céu limpo     Não           Sim  Inverno
# 3               0.0  Céu limpo     Não           Sim  Inverno
# 4               6.5  Céu limpo     Não           Sim  Inverno

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_hora         17414 non-null  datetime64[ns]
#  1   contagem          17414 non-null  int64
#  2   temperatura       17414 non-null  float64
#  3   sensacao_termica  17414 non-null  float64
#  4   umidade           17414 non-null  float64
#  5   velocidade_vento  17414 non-null  float64
#  6   clima             17414 non-null  object
#  7   feriado           17414 non-null  object
#  8   fim_de_semana     17414 non-null  object
#  9   estacao           17414 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df_data['mes'] = df_data['data_hora'].dt.month
df_data['horario'] = df_data['data_hora'].dt.hour

# %%
df_data.head()
# Out:
#             data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0 2015-01-04 00:00:00       182         3.00              2.00     93.0
# 1 2015-01-04 01:00:00       138         2.75              2.25     93.0
# 2 2015-01-04 02:00:00       134         2.50              2.50     96.5
# 3 2015-01-04 03:00:00        72         2.00              2.00    100.0
# 4 2015-01-04 04:00:00        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao  mes  horario
# 0               6.0    Nublado     Não           Sim  Inverno    1        0
# 1               5.0  Céu limpo     Não           Sim  Inverno    1        1
# 2               0.0  Céu limpo     Não           Sim  Inverno    1        2
# 3               0.0  Céu limpo     Não           Sim  Inverno    1        3
# 4               6.5  Céu limpo     Não           Sim  Inverno    1        4

# %%
df_data['data_hora'] = df_data['data_hora'].dt.date
df_data.head()
# Out:
#     data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04       182         3.00              2.00     93.0
# 1  2015-01-04       138         2.75              2.25     93.0
# 2  2015-01-04       134         2.50              2.50     96.5
# 3  2015-01-04        72         2.00              2.00    100.0
# 4  2015-01-04        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao  mes  horario
# 0               6.0    Nublado     Não           Sim  Inverno    1        0
# 1               5.0  Céu limpo     Não           Sim  Inverno    1        1
# 2               0.0  Céu limpo     Não           Sim  Inverno    1        2
# 3               0.0  Céu limpo     Não           Sim  Inverno    1        3
# 4               6.5  Céu limpo     Não           Sim  Inverno    1        4

# %%
df_data = df_data.rename(columns = {'data_hora':'data'})
df_data.head()
# Out:
#          data  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04       182         3.00              2.00     93.0
# 1  2015-01-04       138         2.75              2.25     93.0
# 2  2015-01-04       134         2.50              2.50     96.5
# 3  2015-01-04        72         2.00              2.00    100.0
# 4  2015-01-04        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao  mes  horario
# 0               6.0    Nublado     Não           Sim  Inverno    1        0
# 1               5.0  Céu limpo     Não           Sim  Inverno    1        1
# 2               0.0  Céu limpo     Não           Sim  Inverno    1        2
# 3               0.0  Céu limpo     Não           Sim  Inverno    1        3
# 4               6.5  Céu limpo     Não           Sim  Inverno    1        4

# %%
df_data['data'] = pd.to_datetime(df_data['data'])
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 0 to 17413
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data              17414 non-null  datetime64[ns]
#  1   contagem          17414 non-null  int64
#  2   temperatura       17414 non-null  float64
#  3   sensacao_termica  17414 non-null  float64
#  4   umidade           17414 non-null  float64
#  5   velocidade_vento  17414 non-null  float64
#  6   clima             17414 non-null  object
#  7   feriado           17414 non-null  object
#  8   fim_de_semana     17414 non-null  object
#  9   estacao           17414 non-null  object
#  10  mes               17414 non-null  int32
#  11  horario           17414 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(1), object(4)
# memory usage: 2.1+ MB

# %%
df_por_hora = df_data.groupby('horario')['contagem'].sum().reset_index()
plt.figure(figsize = (8,4))
sns.barplot(data = df_por_hora, x='horario', y='contagem')
plt.title('Bicicletas alugadas por hora')
plt.xlabel('Horario do Dia')
plt.ylabel('Contagem de aluguéis')
plt.show()

# %%
df_fim_de_semna = df_data[df_data['fim_de_semana'] == 'Sim']

alugueis_fim_de_semana = df_fim_de_semna.groupby('horario')['contagem'].sum().reset_index()
plt.figure(figsize = (8,4))
sns.barplot(data = alugueis_fim_de_semana, x='horario', y='contagem')
plt.title('Bicicletas alugadas por hora (FINAL DE SEMANA)')
plt.xlabel('Horario do Dia')
plt.ylabel('Contagem de aluguéis')
plt.show()

# %%
df_feriado = df_data[df_data['feriado'] == 'Sim']

alugueis_feriado = df_feriado.groupby('horario')['contagem'].sum().reset_index()
plt.figure(figsize = (8,4))
sns.barplot(data = alugueis_feriado, x='horario', y='contagem')
plt.title('Bicicletas alugadas por hora (FERIADO)')
plt.xlabel('Horario do Dia')
plt.ylabel('Contagem de aluguéis')
plt.show()

# %%
df_tempo = df_data.groupby('data')['contagem'].sum().reset_index()
plt.figure(figsize = (12,6))
sns.lineplot(data=df_tempo,  x='data', y='contagem')
plt.title('Numero de aluguéis por data')
plt.xlabel('Data')
plt.ylabel('Contagem de aluguéis')
plt.show()

# %%
alugueis_mensais = df_data.groupby('mes')['contagem'].sum().reset_index()
plt.figure(figsize = (6,4))
sns.barplot(data=alugueis_mensais,  x='mes', y='contagem')
plt.title('Numero de aluguéis por Mês')
plt.xlabel('Mês')
plt.ylabel('Contagem de aluguéis')
plt.show()

# %% [markdown]
# ## AULA 05

# %%
from prophet import Prophet

# %%
df_prophet = df_data[['data', 'contagem']].rename(columns= {'data': 'ds', 'contagem':'y'})
df_prophet.head()
# Out:
#           ds    y
# 0 2015-01-04  182
# 1 2015-01-04  138
# 2 2015-01-04  134
# 3 2015-01-04   72
# 4 2015-01-04   47

# %%
df_prophet = df_prophet.groupby('ds')['y'].sum().reset_index()
df_prophet
# Out:
#             ds      y
# 0   2015-01-04   9234
# 1   2015-01-05  20372
# 2   2015-01-06  20613
# 3   2015-01-07  21064
# 4   2015-01-08  15601
# ..         ...    ...
# 725 2016-12-30  11566
# 726 2016-12-31  11424
# 727 2017-01-01   6421
# 728 2017-01-02  11823
# 729 2017-01-03  19436
#
# [730 rows x 2 columns]

# %%
import numpy as np
np.random.seed(4587)

modelo = Prophet()

modelo.fit(df_prophet)
futuro = modelo.make_future_dataframe(periods= 90, freq = 'D')
previsao = modelo.predict(futuro)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/i9jpa1sy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/ubya695q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71744', 'data', 'file=/tmp/tmpblrowvqr/i9jpa1sy.json', 'init=/tmp/tmpblrowvqr/ubya695q.json', 'output', 'file=/tmp/tmpblrowvqr/prophet_modelylylhadu/prophet_model-20250725173201.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:32:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:32:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
fig1 = modelo.plot(previsao)

# %%
previsao[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 0   2015-01-04  10901.148240   4272.992256  17164.501687
# 1   2015-01-05  15311.232708   8913.287413  22636.582586
# 2   2015-01-06  18014.350866  11829.942639  24414.201504
# 3   2015-01-07  18744.719144  12344.154062  25364.884607
# 4   2015-01-08  19556.191727  12809.812197  26023.639264
# ..         ...           ...           ...           ...
# 815 2017-03-30  27262.740955  20840.917738  34360.842038
# 816 2017-03-31  25490.750990  19305.507172  31997.954460
# 817 2017-04-01  21173.750109  15400.577315  27665.232260
# 818 2017-04-02  20856.740496  14700.917577  27176.730648
# 819 2017-04-03  25249.651434  19148.109285  32106.958345
#
# [820 rows x 4 columns]

# %%
fig2 = modelo.plot_components(previsao)

# %%
df_prophet.shape
# Out:
# (730, 2)

# %%
df_treino = pd.DataFrame()

df_treino['ds'] = df_prophet['ds'][:584]
df_treino['y'] = df_prophet['y'][:584]

# %%
df_teste = pd.DataFrame()

df_teste['ds'] = df_prophet['ds'][584:]
df_teste['y'] = df_prophet['y'][584:]

# %%
np.random.seed(4587)

modelo = Prophet()

modelo.fit(df_treino)
futuro = modelo.make_future_dataframe(periods= 150, freq = 'D')
previsao = modelo.predict(futuro)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/9e_1k1d2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/xt77p3mj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11070', 'data', 'file=/tmp/tmpblrowvqr/9e_1k1d2.json', 'init=/tmp/tmpblrowvqr/xt77p3mj.json', 'output', 'file=/tmp/tmpblrowvqr/prophet_modelhepi8cb9/prophet_model-20250725175951.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:59:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:59:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
fig1 = modelo.plot(previsao)
plt.plot(df_teste['ds'], df_teste['y'], '.r')

# %%
fig2 = modelo.plot_components(previsao)

# %%
df_previsao = previsao[['ds', 'yhat']]
df_comparacao = pd.merge(df_previsao, df_teste, on = 'ds')
df_comparacao
# Out:
#             ds          yhat      y
# 0   2016-08-10  40646.666399  38430
# 1   2016-08-11  41387.553580  37626
# 2   2016-08-12  39717.735888  40159
# 3   2016-08-13  35936.820545  43041
# 4   2016-08-14  34777.785741  43848
# ..         ...           ...    ...
# 141 2016-12-30  54505.511686  11566
# 142 2016-12-31  50724.596343  11424
# 143 2017-01-01  49565.561539   6421
# 144 2017-01-02  53551.536790  11823
# 145 2017-01-03  55713.285077  19436
#
# [146 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(df_comparacao['y'],df_comparacao['yhat'])
rmse = np.sqrt(mse)
print(f'MSE: {mse}, RMSE: {rmse}')
# Out:
# MSE: 466132050.6184666, RMSE: 21590.09149166503

# %% [markdown]
# ## AULA 06

# %%
np.random.seed(4587)

modelo = Prophet(yearly_seasonality=True)

modelo.fit(df_treino)
futuro = modelo.make_future_dataframe(periods= 150, freq = 'D')
previsao = modelo.predict(futuro)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/yjm_24qg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/w_rqzclp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6426', 'data', 'file=/tmp/tmpblrowvqr/yjm_24qg.json', 'init=/tmp/tmpblrowvqr/w_rqzclp.json', 'output', 'file=/tmp/tmpblrowvqr/prophet_model7wuk3aig/prophet_model-20250725193758.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:37:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:37:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
fig1 = modelo.plot(previsao)
plt.plot(df_teste['ds'], df_teste['y'], '.r')

# %%
fig2 = modelo.plot_components(previsao)

# %%
df_previsao = previsao[['ds', 'yhat']]
df_comparacao = pd.merge(df_previsao, df_teste, on = 'ds')
df_comparacao
# Out:
#             ds          yhat      y
# 0   2016-08-10  38465.369605  38430
# 1   2016-08-11  38747.157010  37626
# 2   2016-08-12  36570.384861  40159
# 3   2016-08-13  32236.934232  43041
# 4   2016-08-14  30495.324496  43848
# ..         ...           ...    ...
# 141 2016-12-30  15472.686807  11566
# 142 2016-12-31  11648.789994  11424
# 143 2017-01-01  10517.646095   6421
# 144 2017-01-02  14573.011741  11823
# 145 2017-01-03  16856.152443  19436
#
# [146 rows x 3 columns]

# %%
mse = mean_squared_error(df_comparacao['y'],df_comparacao['yhat'])
rmse = np.sqrt(mse)
print(f'MSE: {mse}, RMSE: {rmse}')
# Out:
# MSE: 38623883.499975376, RMSE: 6214.8116222437

# %%
df_prophet
# Out:
#             ds      y
# 0   2015-01-04   9234
# 1   2015-01-05  20372
# 2   2015-01-06  20613
# 3   2015-01-07  21064
# 4   2015-01-08  15601
# ..         ...    ...
# 725 2016-12-30  11566
# 726 2016-12-31  11424
# 727 2017-01-01   6421
# 728 2017-01-02  11823
# 729 2017-01-03  19436
#
# [730 rows x 2 columns]

# %%
np.random.seed(4587)

modelo = Prophet()

modelo.fit(df_prophet)
futuro = modelo.make_future_dataframe(periods= 0)
previsao = modelo.predict(futuro)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/lsy45s2p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/bfs_s1c5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96600', 'data', 'file=/tmp/tmpblrowvqr/lsy45s2p.json', 'init=/tmp/tmpblrowvqr/bfs_s1c5.json', 'output', 'file=/tmp/tmpblrowvqr/prophet_modelmhe59e4l/prophet_model-20250725195813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:58:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:58:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
sem_outliers = df_prophet[(df_prophet['y'] > previsao['yhat_lower']) & (df_prophet['y'] < previsao['yhat_upper'])]

# %%
sem_outliers
# Out:
#             ds      y
# 0   2015-01-04   9234
# 1   2015-01-05  20372
# 2   2015-01-06  20613
# 3   2015-01-07  21064
# 4   2015-01-08  15601
# ..         ...    ...
# 725 2016-12-30  11566
# 726 2016-12-31  11424
# 727 2017-01-01   6421
# 728 2017-01-02  11823
# 729 2017-01-03  19436
#
# [631 rows x 2 columns]

# %%
df_treino = pd.DataFrame()

df_treino['ds'] = sem_outliers['ds'][:505]
df_treino['y'] = sem_outliers['y'][:505]

# %%
df_teste = pd.DataFrame()

df_teste['ds'] = sem_outliers['ds'][505:]
df_teste['y'] = sem_outliers['y'][505:]

# %%
np.random.seed(4587)

modelo_sem_outliers = Prophet(yearly_seasonality=True)

modelo_sem_outliers.fit(df_treino)
futuro = modelo_sem_outliers.make_future_dataframe(periods= 150,  freq = 'D')
previsao = modelo_sem_outliers.predict(futuro)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/6h2v3b96.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/8eszg863.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29436', 'data', 'file=/tmp/tmpblrowvqr/6h2v3b96.json', 'init=/tmp/tmpblrowvqr/8eszg863.json', 'output', 'file=/tmp/tmpblrowvqr/prophet_modellu24qyp6/prophet_model-20250725204800.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:48:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:48:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
fig1 = modelo_sem_outliers.plot(previsao)
plt.plot(df_teste['ds'], df_teste['y'], '.r')

# %%
df_previsao = previsao[['ds', 'yhat']]
df_comparacao = pd.merge(df_previsao, df_teste, on = 'ds')
df_comparacao
# Out:
#             ds          yhat      y
# 0   2016-08-10  38124.205916  38430
# 1   2016-08-11  37708.703632  37626
# 2   2016-08-12  36664.046726  40159
# 3   2016-08-15  34692.056037  40236
# 4   2016-08-16  35633.113613  38911
# ..         ...           ...    ...
# 121 2016-12-30  16752.064183  11566
# 122 2016-12-31  11045.380016  11424
# 123 2017-01-01  10626.497538   6421
# 124 2017-01-02  16230.512446  11823
# 125 2017-01-03  17799.914091  19436
#
# [126 rows x 3 columns]

# %%
mse = mean_squared_error(df_comparacao['y'],df_comparacao['yhat'])
rmse = np.sqrt(mse)
print(f'MSE: {mse}, RMSE: {rmse}')
# Out:
# MSE: 15672925.764235971, RMSE: 3958.904616713564

# %%
from prophet.plot import plot_plotly, plot_components_plotly

# %%
plot_plotly(modelo_sem_outliers, previsao)
plot_components_plotly(modelo_sem_outliers, previsao)
# Out:
# /usr/local/lib/python3.11/dist-packages/plotly/io/_json.py:560: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3012d726-d423-4e2c-a5e2-4d67906763f9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3012d726-d423-4e2c-a5e2-4d67906763f9")) {                    Plotly.newPlot(                        "3012d726-d423-4e2c-a5e2-4d67906763f9",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-30T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-06T00:00:00","2015-06-08T00:00:00","2015-06-09T00:00:00","2015-06-10T00:00:00","2015-06-11T00:00:00","2015-06-12T00:00:00","2015-06-13T00:00:00","2015-06-14T00:00:00","2015-06-15T00:00:00","2015-06-16T00:00:00","2015-06-17T00:00:00","2015-06-18T00:00:00","2015-06-19T00:00:00","2015-06-20T00:00: ...

# %%
np.random.seed(4587)

modelo_sem_outliers = Prophet(yearly_seasonality=True)

modelo_sem_outliers.fit(df_treino)
futuro = modelo_sem_outliers.make_future_dataframe(periods= 365,  freq = 'D')
previsao = modelo_sem_outliers.predict(futuro)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/l1soms45.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpblrowvqr/c2079z8f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29448', 'data', 'file=/tmp/tmpblrowvqr/l1soms45.json', 'init=/tmp/tmpblrowvqr/c2079z8f.json', 'output', 'file=/tmp/tmpblrowvqr/prophet_modeluhrz6i19/prophet_model-20250725205612.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:56:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:56:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
fig = plot_plotly(modelo_sem_outliers, previsao)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc41fb53-a0df-46af-a134-8cb2dce502a6" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc41fb53-a0df-46af-a134-8cb2dce502a6")) {                    Plotly.newPlot(                        "dc41fb53-a0df-46af-a134-8cb2dce502a6",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-30T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-06T00:00:00","2015-06-08T00:00:00","2015-06-09T00:00:00","2015-06-10T00:00:00","2015-06-11T00:00:00","2015-06-12T00:00:00","2015-06-13T00:00:00","2015-06-14T00:00:00","2015-06-15T00:00:00","2015-06-16T00:00:00","2015-06-17T00:00:00","2015-06-18T00:00:00","2015-06-19T00:00:00","2015-06-20T00:0 ...

# %% [markdown]
# # ATIVIDADES DAS AULAS

# %% [markdown]
# ## AULA 04

# %%
df_tempo_diferente = df_data.groupby('data')['contagem'].sum().reset_index()

# %%
df_tempo_diferente['mes'] = df_tempo_diferente['data'].dt.to_period('M')
df_tempo_diferente
# Out:
#           data  contagem      mes
# 0   2015-01-04      9234  2015-01
# 1   2015-01-05     20372  2015-01
# 2   2015-01-06     20613  2015-01
# 3   2015-01-07     21064  2015-01
# 4   2015-01-08     15601  2015-01
# ..         ...       ...      ...
# 725 2016-12-30     11566  2016-12
# 726 2016-12-31     11424  2016-12
# 727 2017-01-01      6421  2017-01
# 728 2017-01-02     11823  2017-01
# 729 2017-01-03     19436  2017-01
#
# [730 rows x 3 columns]

# %%
media_alugueis_por_mes= df_tempo_diferente.groupby('mes')['contagem'].mean().reset_index()

# %%
media_alugueis_por_mes.head()
# Out:
#        mes      contagem
# 0  2015-01  19522.821429
# 1  2015-02  19414.071429
# 2  2015-03  22449.483871
# 3  2015-04  27719.400000
# 4  2015-05  28884.290323

# %%
plt.figure(figsize = (20,4))
sns.barplot(data=media_alugueis_por_mes,  x='mes', y='contagem')
plt.title('Média de aluguéis por Mês')
plt.xlabel('Mês')
plt.ylabel('Média de aluguéis')
plt.show()
